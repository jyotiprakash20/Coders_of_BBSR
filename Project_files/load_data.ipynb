# %%
import json

# %%
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
    return data

# %%
data=load_data("data.json")
data
# Out:
# {'users': [{'id': 1, 'name': 'Jyoti', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Soyam', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Bignesh', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Alok', 'friends': [2], 'liked_pages': [104]},
#   {'id': 5, 'name': 'Ayush', 'friends': [1, 3], 'liked_pages': [103]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
def display_user(data):
    print('users information')  
    for user in data['users']:
        print(f'ID {user['id']}: {user['name']} is friends with: {user['friends']} and liked pages are {user['liked_pages']}')
    print('\npages information')
    for page in data['pages']:
        print(f'{page['id']}: {page['name']}')

display_user(data)
# Out:
# users information
# ID 1: Jyoti is friends with: [2, 3] and liked pages are [101]
# ID 2: Soyam is friends with: [1, 4] and liked pages are [102]
# ID 3: Bignesh is friends with: [1] and liked pages are [101, 103]
# ID 4: Alok is friends with: [2] and liked pages are [104]
# ID 5: Ayush is friends with: [1, 3] and liked pages are [103]
#
# pages information
# 101: Python Developers
# 102: Data Science Enthusiasts
# 103: AI & ML Community
# 104: Web Dev Hub
